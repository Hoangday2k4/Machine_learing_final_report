# %% [markdown]
# # Machine learing demo code use Numpy

# %% [markdown]
# ## Đọc dữ liệu

# %%
import pandas as pd

# Replace with the actual file path if needed
data = pd.read_excel('D:\\Machine_learning\\Data_project\\dataset_02052023.xlsx')
print(data)
# Out:
#        Num                 Timestamp  Current_J0  Temperature_T0  Current_J1  \
# 0        1  2022-10-26T08:17:21.847Z    0.109628         27.8750   -2.024669
# 1        2  2022-10-26T08:17:22.852Z    0.595605         27.8750   -2.278456
# 2        3  2022-10-26T08:17:23.857Z   -0.229474         27.8750   -2.800408
# 3        4  2022-10-26T08:17:24.863Z    0.065053         27.8750   -3.687768
# 4        5  2022-10-26T08:17:25.877Z    0.884140         27.8750   -2.938830
# ...    ...                       ...         ...             ...         ...
# 7404  7405  2022-10-26T15:36:02.555Z   -0.109017         37.1875   -2.261695
# 7405  7406  2022-10-26T15:36:03.562Z   -0.098536         37.1875   -2.251992
# 7406  7407  2022-10-26T15:36:04.571Z   -0.121100         37.1875   -2.280791
# 7407  7408  2022-10-26T15:36:05.572Z   -0.129370         37.1875   -2.269061
# 7408  7409  2022-10-26T15:36:06.580Z   -0.134429         37.1250   -2.244449
#
#       Temperature_J1  Current_J2  Temperature_J2  Current_J3  Temperature_J3  \
# 0            29.3750   -1.531442         29.3750   -0.998570         32.1250
# 1            29.3125   -0.866556         29.4375   -0.206097         32.1875
# 2            29.3125   -2.304336         29.4375   -0.351499         32.1250
# 3            29.3125   -1.217652         29.4375   -1.209115         32.1250
# 4            29.3750   -1.794076         29.4375   -2.356471         32.1875
# ...              ...         ...             ...         ...             ...
# 7404         40.3125   -1.082678         40.6875   -0.494714         43.3750
# 7405         40.3125   -1.094420         40.6875   -0.515789         43.3750
# 7406         40.2500   -1.121319         40.6875   -0.502406         43.3750
# 7407         40.3125   -1.091610         40.6250   -0.491158         43.3750
# 7408         40.3125   -1.098950         40.6875   -0.502397         43.3750
#
#       ...      Speed_J0  Speed_J1  Speed_J2  Speed_J3  Speed_J4  Speed_J5  \
# 0     ...  2.955651e-01 -0.000490  0.001310 -0.132836 -0.007479 -0.152962
# 1     ... -7.391485e-30 -0.000304  0.002185  0.001668 -0.000767  0.000417
# 2     ...  1.369386e-01  0.007795 -2.535874  0.379867  0.000455 -0.496856
# 3     ... -9.030032e-02 -0.004911 -0.009096 -0.384196  0.018411  0.425559
# 4     ...  1.268088e-01  0.005567  0.001138 -0.353284  0.014994  0.180989
# ...   ...           ...       ...       ...       ...       ...       ...
# 7404  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7405  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7406  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7407  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7408  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
#
#       Tool_current  cycle   Robot_ProtectiveStop  grip_lost
# 0         0.082732       1                   0.0      False
# 1         0.505895       1                   0.0      False
# 2         0.079420       1                   0.0      False
# 3         0.083325       1                   0.0      False
# 4         0.086379       1                   0.0      False
# ...            ...     ...                   ...        ...
# 7404      0.080013     264                   0.0      False
# 7405      0.078740     264                   0.0      False
# 7406      0.091471     264                   0.0      False
# 7407      0.090026     264                   0.0      False
# 7408      0.089097     264                   0.0      False
#
# [7409 rows x 24 columns]

# %% [markdown]
# ## Tiền Xử lý dữ liệu:

# %%
# Kiểm tra các giá trị bị thiếu
print(data.isnull().sum())
# Out:
# Num                      0
# Timestamp                0
# Current_J0              46
# Temperature_T0          54
# Current_J1              54
# Temperature_J1          54
# Current_J2              54
# Temperature_J2          54
# Current_J3              54
# Temperature_J3          54
# Current_J4              54
# Temperature_J4          54
# Current_J5              54
# Temperature_J5          54
# Speed_J0                54
# Speed_J1                54
# Speed_J2                54
# Speed_J3                54
# Speed_J4                54
# Speed_J5                54
# Tool_current            54
# cycle                    0
# Robot_ProtectiveStop    54
# grip_lost                0
# dtype: int64

# %%
# Thay giá trị bị thiếu bằng giá trị trung vị (Median) của cột
for i in {"Current_J0", "Temperature_T0", "Current_J1", "Temperature_J1", "Current_J2", "Temperature_J2", "Current_J3", "Temperature_J3", 
          "Current_J4", "Temperature_J4", "Current_J5", "Temperature_J5", 
          "Speed_J0", "Speed_J1", "Speed_J2", "Speed_J3", "Speed_J4", "Speed_J5", 
          "Tool_current", "Robot_ProtectiveStop"}:
    data[i].fillna(data[i].median(), inplace=True)

print(data.isnull().sum())
print(data)
# Out:
# Num                     0
# Timestamp               0
# Current_J0              0
# Temperature_T0          0
# Current_J1              0
# Temperature_J1          0
# Current_J2              0
# Temperature_J2          0
# Current_J3              0
# Temperature_J3          0
# Current_J4              0
# Temperature_J4          0
# Current_J5              0
# Temperature_J5          0
# Speed_J0                0
# Speed_J1                0
# Speed_J2                0
# Speed_J3                0
# Speed_J4                0
# Speed_J5                0
# Tool_current            0
# cycle                   0
# Robot_ProtectiveStop    0
# grip_lost               0
# dtype: int64
#        Num                 Timestamp  Current_J0  Temperature_T0  Current_J1  \
# 0        1  2022-10-26T08:17:21.847Z    0.109628         27.8750   -2.024669
# 1        2  2022-10-26T08:17:22.852Z    0.595605         27.8750   -2.278456
# 2        3  2022-10-26T08:17:23.857Z   -0.229474         27.8750   -2.800408
# 3        4  2022-10-26T08:17:24.863Z    0.065053         27.8750   -3.687768
# 4        5  2022-10-26T08:17:25.877Z    0.884140         27.8750   -2.938830
# ...    ...                       ...         ...             ...         ...
# 7404  7405  2022-10-26T15:36:02.555Z   -0.109017         37.1875   -2.261695
# 7405  7406  2022-10-26T15:36:03.562Z   -0.098536         37.1875   -2.251992
# 7406  7407  2022-10-26T15:36:04.571Z   -0.121100         37.1875   -2.280791
# 7407  7408  2022-10-26T15:36:05.572Z   -0.129370         37.1875   -2.269061
# 7408  7409  2022-10-26T15:36:06.580Z   -0.134429         37.1250   -2.244449
#
#       Temperature_J1  Current_J2  Temperature_J2  Current_J3  Temperature_J3  \
# 0            29.3750   -1.531442         29.3750   -0.998570         32.1250
# 1            29.3125   -0.866556         29.4375   -0.206097         32.1875
# 2            29.3125   -2.304336         29.4375   -0.351499         32.1250
# 3            29.3125   -1.217652         29.4375   -1.209115         32.1250
# 4            29.3750   -1.794076         29.4375   -2.356471         32.1875
# ...              ...         ...             ...         ...             ...
# 7404         40.3125   -1.082678         40.6875   -0.494714         43.3750
# 7405         40.3125   -1.094420         40.6875   -0.515789         43.3750
# 7406         40.2500   -1.121319         40.6875   -0.502406         43.3750
# 7407         40.3125   -1.091610         40.6250   -0.491158         43.3750
# 7408         40.3125   -1.098950         40.6875   -0.502397         43.3750
#
#       ...      Speed_J0  Speed_J1  Speed_J2  Speed_J3  Speed_J4  Speed_J5  \
# 0     ...  2.955651e-01 -0.000490  0.001310 -0.132836 -0.007479 -0.152962
# 1     ... -7.391485e-30 -0.000304  0.002185  0.001668 -0.000767  0.000417
# 2     ...  1.369386e-01  0.007795 -2.535874  0.379867  0.000455 -0.496856
# 3     ... -9.030032e-02 -0.004911 -0.009096 -0.384196  0.018411  0.425559
# 4     ...  1.268088e-01  0.005567  0.001138 -0.353284  0.014994  0.180989
# ...   ...           ...       ...       ...       ...       ...       ...
# 7404  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7405  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7406  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7407  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7408  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
#
#       Tool_current  cycle   Robot_ProtectiveStop  grip_lost
# 0         0.082732       1                   0.0      False
# 1         0.505895       1                   0.0      False
# 2         0.079420       1                   0.0      False
# 3         0.083325       1                   0.0      False
# 4         0.086379       1                   0.0      False
# ...            ...     ...                   ...        ...
# 7404      0.080013     264                   0.0      False
# 7405      0.078740     264                   0.0      False
# 7406      0.091471     264                   0.0      False
# 7407      0.090026     264                   0.0      False
# 7408      0.089097     264                   0.0      False
#
# [7409 rows x 24 columns]
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_8928\1713655945.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].median(), inplace=True)

# %%
# Chuyển các giá trị boolean thành giá trị số
# Quy ước True = 1, False = 0
for col in data.columns:
    if data[col].dtype == 'bool':  # Kiểu dữ liệu Boolean
        data[col] = data[col].astype(int)
    elif data[col].isin(['True', 'False']).all():  # Kiểm tra nếu cột chứa chuỗi True/False
        data[col] = data[col].replace({'True': 1, 'False': 0})
print(data)
# Out:
#        Num                 Timestamp  Current_J0  Temperature_T0  Current_J1  \
# 0        1  2022-10-26T08:17:21.847Z    0.109628         27.8750   -2.024669
# 1        2  2022-10-26T08:17:22.852Z    0.595605         27.8750   -2.278456
# 2        3  2022-10-26T08:17:23.857Z   -0.229474         27.8750   -2.800408
# 3        4  2022-10-26T08:17:24.863Z    0.065053         27.8750   -3.687768
# 4        5  2022-10-26T08:17:25.877Z    0.884140         27.8750   -2.938830
# ...    ...                       ...         ...             ...         ...
# 7404  7405  2022-10-26T15:36:02.555Z   -0.109017         37.1875   -2.261695
# 7405  7406  2022-10-26T15:36:03.562Z   -0.098536         37.1875   -2.251992
# 7406  7407  2022-10-26T15:36:04.571Z   -0.121100         37.1875   -2.280791
# 7407  7408  2022-10-26T15:36:05.572Z   -0.129370         37.1875   -2.269061
# 7408  7409  2022-10-26T15:36:06.580Z   -0.134429         37.1250   -2.244449
#
#       Temperature_J1  Current_J2  Temperature_J2  Current_J3  Temperature_J3  \
# 0            29.3750   -1.531442         29.3750   -0.998570         32.1250
# 1            29.3125   -0.866556         29.4375   -0.206097         32.1875
# 2            29.3125   -2.304336         29.4375   -0.351499         32.1250
# 3            29.3125   -1.217652         29.4375   -1.209115         32.1250
# 4            29.3750   -1.794076         29.4375   -2.356471         32.1875
# ...              ...         ...             ...         ...             ...
# 7404         40.3125   -1.082678         40.6875   -0.494714         43.3750
# 7405         40.3125   -1.094420         40.6875   -0.515789         43.3750
# 7406         40.2500   -1.121319         40.6875   -0.502406         43.3750
# 7407         40.3125   -1.091610         40.6250   -0.491158         43.3750
# 7408         40.3125   -1.098950         40.6875   -0.502397         43.3750
#
#       ...      Speed_J0  Speed_J1  Speed_J2  Speed_J3  Speed_J4  Speed_J5  \
# 0     ...  2.955651e-01 -0.000490  0.001310 -0.132836 -0.007479 -0.152962
# 1     ... -7.391485e-30 -0.000304  0.002185  0.001668 -0.000767  0.000417
# 2     ...  1.369386e-01  0.007795 -2.535874  0.379867  0.000455 -0.496856
# 3     ... -9.030032e-02 -0.004911 -0.009096 -0.384196  0.018411  0.425559
# 4     ...  1.268088e-01  0.005567  0.001138 -0.353284  0.014994  0.180989
# ...   ...           ...       ...       ...       ...       ...       ...
# 7404  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7405  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7406  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7407  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7408  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
#
#       Tool_current  cycle   Robot_ProtectiveStop  grip_lost
# 0         0.082732       1                   0.0          0
# 1         0.505895       1                   0.0          0
# 2         0.079420       1                   0.0          0
# 3         0.083325       1                   0.0          0
# 4         0.086379       1                   0.0          0
# ...            ...     ...                   ...        ...
# 7404      0.080013     264                   0.0          0
# 7405      0.078740     264                   0.0          0
# 7406      0.091471     264                   0.0          0
# 7407      0.090026     264                   0.0          0
# 7408      0.089097     264                   0.0          0
#
# [7409 rows x 24 columns]

# %% [markdown]
# ## Giảm chiều dữ liệu

# %%
import copy
features = copy.deepcopy(data)
print(features)
# Out:
#        Num                 Timestamp  Current_J0  Temperature_T0  Current_J1  \
# 0        1  2022-10-26T08:17:21.847Z    0.109628         27.8750   -2.024669
# 1        2  2022-10-26T08:17:22.852Z    0.595605         27.8750   -2.278456
# 2        3  2022-10-26T08:17:23.857Z   -0.229474         27.8750   -2.800408
# 3        4  2022-10-26T08:17:24.863Z    0.065053         27.8750   -3.687768
# 4        5  2022-10-26T08:17:25.877Z    0.884140         27.8750   -2.938830
# ...    ...                       ...         ...             ...         ...
# 7404  7405  2022-10-26T15:36:02.555Z   -0.109017         37.1875   -2.261695
# 7405  7406  2022-10-26T15:36:03.562Z   -0.098536         37.1875   -2.251992
# 7406  7407  2022-10-26T15:36:04.571Z   -0.121100         37.1875   -2.280791
# 7407  7408  2022-10-26T15:36:05.572Z   -0.129370         37.1875   -2.269061
# 7408  7409  2022-10-26T15:36:06.580Z   -0.134429         37.1250   -2.244449
#
#       Temperature_J1  Current_J2  Temperature_J2  Current_J3  Temperature_J3  \
# 0            29.3750   -1.531442         29.3750   -0.998570         32.1250
# 1            29.3125   -0.866556         29.4375   -0.206097         32.1875
# 2            29.3125   -2.304336         29.4375   -0.351499         32.1250
# 3            29.3125   -1.217652         29.4375   -1.209115         32.1250
# 4            29.3750   -1.794076         29.4375   -2.356471         32.1875
# ...              ...         ...             ...         ...             ...
# 7404         40.3125   -1.082678         40.6875   -0.494714         43.3750
# 7405         40.3125   -1.094420         40.6875   -0.515789         43.3750
# 7406         40.2500   -1.121319         40.6875   -0.502406         43.3750
# 7407         40.3125   -1.091610         40.6250   -0.491158         43.3750
# 7408         40.3125   -1.098950         40.6875   -0.502397         43.3750
#
#       ...      Speed_J0  Speed_J1  Speed_J2  Speed_J3  Speed_J4  Speed_J5  \
# 0     ...  2.955651e-01 -0.000490  0.001310 -0.132836 -0.007479 -0.152962
# 1     ... -7.391485e-30 -0.000304  0.002185  0.001668 -0.000767  0.000417
# 2     ...  1.369386e-01  0.007795 -2.535874  0.379867  0.000455 -0.496856
# 3     ... -9.030032e-02 -0.004911 -0.009096 -0.384196  0.018411  0.425559
# 4     ...  1.268088e-01  0.005567  0.001138 -0.353284  0.014994  0.180989
# ...   ...           ...       ...       ...       ...       ...       ...
# 7404  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7405  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7406  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7407  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7408  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
#
#       Tool_current  cycle   Robot_ProtectiveStop  grip_lost
# 0         0.082732       1                   0.0          0
# 1         0.505895       1                   0.0          0
# 2         0.079420       1                   0.0          0
# 3         0.083325       1                   0.0          0
# 4         0.086379       1                   0.0          0
# ...            ...     ...                   ...        ...
# 7404      0.080013     264                   0.0          0
# 7405      0.078740     264                   0.0          0
# 7406      0.091471     264                   0.0          0
# 7407      0.090026     264                   0.0          0
# 7408      0.089097     264                   0.0          0
#
# [7409 rows x 24 columns]

# %% [markdown]
# *  Principal Component Analysis (PCA)

# %%
from pca_Object import PCA_Object
from draw_Graph import ScatterPlot

# Loại các cột không phải là số
features_PCA = features.select_dtypes(include=['float64', 'int64'])

# Apply PCA
pca = PCA_Object(n_components=2)  # Giảm xuống 2 thành phần chính
reduced_PCA = pca.fit_transform(features_PCA)

# Vẽ biểu đồ scatter plot
scatter_plot = ScatterPlot(figsize=(8, 6))

scatter_plot.plot_1(
    x=reduced_PCA[:, 0],
    y=reduced_PCA[:, 1],
    c='blue',
    edgecolor='k',
    alpha=0.7,
    title='Biểu đồ phân tán của PCA (2 Thành phần chính)',
    xlabel='Thành phần chính 1',
    ylabel='Thành phần chính 2',
    grid=True
)

# %% [markdown]
# * Linear Discriminant Analysis (LDA)

# %%
from lda_Object import LDA_Object
from draw_Graph import ScatterPlot

# Tách đặc trưng (features) và nhãn (target)
X = features.select_dtypes(include=['float64', 'int64'])  # Các cột đặc trưng số

# Tìm nhãn cho dữ liệu
from sklearn.cluster import KMeans
# Áp dụng K-Means để phân cụm
kmeans = KMeans(n_clusters=3, random_state=42)  # Chia thành 3 cụm
labels = kmeans.fit_predict(X)

# Thêm nhãn vào DataFrame
features['label'] = labels
y = features['label']  # Thay 'label' bằng tên cột chứa nhãn (target)

# Áp dụng LDA
lda = LDA_Object(n_components=2)  # Giảm xuống 2 thành phần
reduced_LDA = lda.fit_transform(X, y)

# Vẽ biểu đồ scatter plot cho LDA
scatter_plot = ScatterPlot(figsize=(8, 6))

scatter_plot.plot_2(
    x=reduced_PCA[:, 0],
    y=reduced_PCA[:, 1],
    c=features['label'],
    cmap='viridis',
    edgecolor='k',
    alpha=0.7,
    title='Biểu đồ phân tán của LDA (2 Thành phần chính)',
    xlabel='Thành phần chính 1',
    ylabel='Thành phần chính 2',
    grid=True
)

# %% [markdown]
# ## Phân cụm dữ liệu

# %% [markdown]
# * Thuật toán KMeans

# %%
from kmeans_Object import KMeans_Object
import copy
# Copy dữ liệu
data_cluster = copy.deepcopy(data)
# Lựa chọn các cột số làm đặc trưng (features)
features = data_cluster.select_dtypes(include=['float64', 'int64'])

# Áp dụng KMeans để phân cụm dữ liệu
kmeans = KMeans_Object(n_clusters=3, random_state=42)  # Số cụm bạn muốn (ở đây là 3)
labels = kmeans.fit_predict(features)

# Thêm nhãn vào DataFrame
data_cluster['label'] = labels
print(labels)
# Out:
# [1 1 1 ... 0 0 0]

# %%
# Vẽ đồ thị phân tán (scatter plot) với 2 thành phần chính của PCA hoặc trực tiếp
from draw_Graph import ScatterPlot
scatter_plot = ScatterPlot(figsize=(8, 6))

scatter_plot.plot_2(
    x=features.iloc[:, 0],
    y=features.iloc[:, 1],
    c=labels,
    cmap='viridis',
    edgecolor='k',
    alpha=0.7,
    title='Biểu đồ phân tán của dữ liệu sau phân cụm KMeans',
    xlabel='Feature 1',
    ylabel='Feature 2',
    grid=True
)

# %% [markdown]
# * Thuật toán DBScan

# %%
from dbscan_Object import DBSCAN_Object

# Lựa chọn các cột số làm đặc trưng (features)
features = data_cluster.select_dtypes(include=['float64', 'int64'])

# Áp dụng DBSCAN để phân cụm dữ liệu
dbscan = DBSCAN_Object(eps=0.5, min_samples=5)  # eps là bán kính khu vực lân cận, min_samples là số lượng điểm tối thiểu trong khu vực để tạo thành một cụm
labels_dbscan = dbscan.fit_predict(features)

# Thêm nhãn vào DataFrame
data_cluster['label_dbscan'] = labels_dbscan
print(labels_dbscan)
print(data)
# Out:
# [-1. -1. -1. ... -1. -1. -1.]
#        Num                 Timestamp  Current_J0  Temperature_T0  Current_J1  \
# 0        1  2022-10-26T08:17:21.847Z    0.109628         27.8750   -2.024669
# 1        2  2022-10-26T08:17:22.852Z    0.595605         27.8750   -2.278456
# 2        3  2022-10-26T08:17:23.857Z   -0.229474         27.8750   -2.800408
# 3        4  2022-10-26T08:17:24.863Z    0.065053         27.8750   -3.687768
# 4        5  2022-10-26T08:17:25.877Z    0.884140         27.8750   -2.938830
# ...    ...                       ...         ...             ...         ...
# 7404  7405  2022-10-26T15:36:02.555Z   -0.109017         37.1875   -2.261695
# 7405  7406  2022-10-26T15:36:03.562Z   -0.098536         37.1875   -2.251992
# 7406  7407  2022-10-26T15:36:04.571Z   -0.121100         37.1875   -2.280791
# 7407  7408  2022-10-26T15:36:05.572Z   -0.129370         37.1875   -2.269061
# 7408  7409  2022-10-26T15:36:06.580Z   -0.134429         37.1250   -2.244449
#
#       Temperature_J1  Current_J2  Temperature_J2  Current_J3  Temperature_J3  \
# 0            29.3750   -1.531442         29.3750   -0.998570         32.1250
# 1            29.3125   -0.866556         29.4375   -0.206097         32.1875
# 2            29.3125   -2.304336         29.4375   -0.351499         32.1250
# 3            29.3125   -1.217652         29.4375   -1.209115         32.1250
# 4            29.3750   -1.794076         29.4375   -2.356471         32.1875
# ...              ...         ...             ...         ...             ...
# 7404         40.3125   -1.082678         40.6875   -0.494714         43.3750
# 7405         40.3125   -1.094420         40.6875   -0.515789         43.3750
# 7406         40.2500   -1.121319         40.6875   -0.502406         43.3750
# 7407         40.3125   -1.091610         40.6250   -0.491158         43.3750
# 7408         40.3125   -1.098950         40.6875   -0.502397         43.3750
#
#       ...      Speed_J0  Speed_J1  Speed_J2  Speed_J3  Speed_J4  Speed_J5  \
# 0     ...  2.955651e-01 -0.000490  0.001310 -0.132836 -0.007479 -0.152962
# 1     ... -7.391485e-30 -0.000304  0.002185  0.001668 -0.000767  0.000417
# 2     ...  1.369386e-01  0.007795 -2.535874  0.379867  0.000455 -0.496856
# 3     ... -9.030032e-02 -0.004911 -0.009096 -0.384196  0.018411  0.425559
# 4     ...  1.268088e-01  0.005567  0.001138 -0.353284  0.014994  0.180989
# ...   ...           ...       ...       ...       ...       ...       ...
# 7404  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7405  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7406  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7407  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 7408  ...  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
#
#       Tool_current  cycle   Robot_ProtectiveStop  grip_lost
# 0         0.082732       1                   0.0          0
# 1         0.505895       1                   0.0          0
# 2         0.079420       1                   0.0          0
# 3         0.083325       1                   0.0          0
# 4         0.086379       1                   0.0          0
# ...            ...     ...                   ...        ...
# 7404      0.080013     264                   0.0          0
# 7405      0.078740     264                   0.0          0
# 7406      0.091471     264                   0.0          0
# 7407      0.090026     264                   0.0          0
# 7408      0.089097     264                   0.0          0
#
# [7409 rows x 24 columns]

# %%
# Vẽ đồ thị phân tán (scatter plot) với 2 thành phần chính của PCA hoặc trực tiếp
from draw_Graph import ScatterPlot
scatter_plot = ScatterPlot(figsize=(8, 6))

scatter_plot.plot_2(
    x=features.iloc[:, 0],
    y=features.iloc[:, 1],
    c=labels_dbscan,
    cmap='viridis',
    edgecolor='k',
    alpha=0.7,
    title='Biểu đồ phân tán của dữ liệu sau phân cụm DBScan',
    xlabel='Feature 1',
    ylabel='Feature 2',
    grid=True
)

# %% [markdown]
# ## Phân loại dữ liệu

# %% [markdown]
# * Naive Bayess

# %% [markdown]
# *
#     * Chuẩn bị dữ liệu

# %%
from sklearn.model_selection import train_test_split

# Tạo nhãn MaintenanceRequired
data['MaintenanceRequired'] = ((data['Robot_ProtectiveStop'] == 1) | (data['grip_lost'] == 1)).astype(int)

# Lựa chọn các cột số làm đặc trưng
features = data[['Current_J0', 'Temperature_T0', 'Current_J1', 'Temperature_J1', 'Current_J2', 
    'Temperature_J2', 'Current_J3', 'Temperature_J3', 'Current_J4', 'Temperature_J4', 
    'Current_J5', 'Temperature_J5', 'Speed_J0', 'Speed_J1', 'Speed_J2', 'Speed_J3', 
    'Speed_J4', 'Speed_J5', 'Tool_current']]

labels = data['MaintenanceRequired']  # Nhãn 0 hoặc 1, xác định có cần bảo trì hay không

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

# %% [markdown]
# *
#     * Gaussian Naive Bayes

# %%
from naive_Bayes_Object import GaussianNB_Object
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Khởi tạo mô hình Naive Bayes
model = GaussianNB_Object()

# Huấn luyện mô hình
model.fit(X_train, y_train)

# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đánh giá mô hình
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# In độ chính xác và ma trận nhầm lẫn
print(f"Độ chính xác: {accuracy * 100:.2f}%")

# Vẽ ma trận nhầm lẫn
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Không cần bảo trì', 'Cần bảo trì'], yticklabels=['Không cần bảo trì', 'Cần bảo trì'])
plt.xlabel('Dự đoán')
plt.ylabel('Thực tế')
plt.title('Ma trận nhầm lẫn của mô hình Gaussian Naive Bayes')
plt.show()
# Out:
# Độ chính xác: 84.03%

# %% [markdown]
# *
#     * Multinomial Naive Bayes

# %%
from naive_Bayes_Object import MultinomialNB_Object
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Khởi tạo mô hình Naive Bayes
model = MultinomialNB_Object()

# Huấn luyện mô hình
model.fit(X_train, y_train)

# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đánh giá mô hình
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# In độ chính xác và ma trận nhầm lẫn
print(f"Độ chính xác: {accuracy * 100:.2f}%")

# Vẽ ma trận nhầm lẫn
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Không cần bảo trì', 'Cần bảo trì'], yticklabels=['Không cần bảo trì', 'Cần bảo trì'])
plt.xlabel('Dự đoán')
plt.ylabel('Thực tế')
plt.title('Ma trận nhầm lẫn của mô hình Multinomial Naive Bayes')
plt.show()
# Out:
# Độ chính xác: 92.71%
# d:\Machine_learning\Data_project\naive_Bayes_Object.py:88: RuntimeWarning: invalid value encountered in log
#   conditional = np.sum(x * np.log(self.likelihoods[cls]))

# %% [markdown]
# *
#     * Bernoulli Naive Bayes

# %%
from naive_Bayes_Object import BernoulliNB_Object
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Khởi tạo mô hình Naive Bayes
model = BernoulliNB_Object()

# Huấn luyện mô hình
model.fit(X_train, y_train)

# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đánh giá mô hình
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# In độ chính xác và ma trận nhầm lẫn
print(f"Độ chính xác: {accuracy * 100:.2f}%")

# Vẽ ma trận nhầm lẫn
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Không cần bảo trì', 'Cần bảo trì'], yticklabels=['Không cần bảo trì', 'Cần bảo trì'])
plt.xlabel('Dự đoán')
plt.ylabel('Thực tế')
plt.title('Ma trận nhầm lẫn của mô hình Bernoulli Naive Bayes')
plt.show()
# Out:
# Độ chính xác: 92.71%
# d:\Machine_learning\Data_project\naive_Bayes_Object.py:116: RuntimeWarning: invalid value encountered in log
#   conditional = np.sum(x * np.log(self.likelihoods[cls]) + (1 - x) * np.log(1 - self.likelihoods[cls]))

# %% [markdown]
# * Perceptron:

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from perceptron_Object import Perceptron_Object
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Tiến hành chuẩn hóa dữ liệu (scaling) vì Perceptron nhạy cảm với tỷ lệ của các đặc trưng
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Khởi tạo mô hình Perceptron và huấn luyện
model = Perceptron_Object()
model.fit(X_train_scaled, y_train)

# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test_scaled)

# Đánh giá mô hình
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# In độ chính xác và ma trận nhầm lẫn
print(f"Độ chính xác: {accuracy * 100:.2f}%")

# Vẽ ma trận nhầm lẫn
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Không cần bảo trì', 'Cần bảo trì'], yticklabels=['Không cần bảo trì', 'Cần bảo trì'])
plt.xlabel('Dự đoán')
plt.ylabel('Thực tế')
plt.title('Ma trận nhầm lẫn của mô hình Perceptron')
plt.show()
# Out:
# Độ chính xác: 88.98%
